# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Churn_Modelling - Churn_Modelling.csv')

# %%
dataset.shape
# Out:
# (10000, 14)

# %%
dataset.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
dataset.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
dataset.shape
# Out:
# (10000, 11)

# %%
dataset['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
dataset['Gender'].value_counts()
# Out:
# Gender
# Male      5457
# Female    4543
# Name: count, dtype: int64

# %%
df = pd.get_dummies(dataset,columns=['Geography','Gender'],drop_first= True)

# %%
df
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1              False
# 1                  1        112542.58       0              False
# 2                  0        113931.57       1              False
# 3                  0         93826.63       0              False
# 4                  1         79084.10       0              False
# ...              ...              ...     ...                ...
# 9995               0         96270.64       0              False
# 9996               1        101699.77       0              False
# 9997               1         42085.58       1              False
# 9998               0         92888.52       1               True
# 9999               0         38190.78       0              False
#
#       Geography_Spain  Gender_Male
# 0               False        False
# 1                True        False
# 2               False        False
# 3               False        False
# 4                True        False
# ...               ...          ...
# 9995            False         True
# 9996            False         True
# 9997            False        False
# 9998            False         True
# 9999            False        False
#
# [10000 rows x 12 columns]

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier1 = Sequential()

# %%
classifier1.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
classifier1.add(Dense(3, kernel_initializer = 'uniform', activation = 'relu'))

# %%
classifier1.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# %%
from tensorflow.keras.optimizers import Adam


classifier1.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss',
                               patience=10,
                               restore_best_weights=True,
                               verbose=1)

# %%
history = classifier1.fit(X_train, y_train,
                    epochs=100,
                    batch_size=66,
                    validation_data=(X_test, y_test),
                    callbacks=[early_stopping],
                    verbose=1)
# Out:
# Epoch 1/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.7934 - loss: 0.6845 - val_accuracy: 0.7975 - val_loss: 0.6595
# Epoch 2/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7941 - loss: 0.6524 - val_accuracy: 0.7975 - val_loss: 0.6310
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8026 - loss: 0.6235 - val_accuracy: 0.7975 - val_loss: 0.6073
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7916 - loss: 0.6041 - val_accuracy: 0.7975 - val_loss: 0.5872
# Epoch 5/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7948 - loss: 0.5841 - val_accuracy: 0.7975 - val_loss: 0.5706
# Epoch 6/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7961 - loss: 0.5678 - val_accuracy: 0.7975 - val_loss: 0.5568
# Epoch 7/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.5594 - val_accuracy: 0.7975 - val_loss: 0.5455
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7864 - loss: 0.5510 - val_accuracy: 0.7975 - val_loss: 0.5364
# Epoch 9/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7982 - loss: 0.5339 - val_accuracy: 0.7975 - val_loss: 0.5290
# Epoch 10/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8007 - loss: 0.5248 - val_accuracy: 0.7975 - val_loss: 0.5232
# Epoch 11/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7967 - loss: 0.5227 - val_accuracy: 0.7975 - val_loss: 0.5185
# Epoch 12/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7923 - loss: 0.5226 - val_accuracy: 0.7975 - val_loss: 0.5148
# Epoch 13/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.5157 - val_accuracy: 0.7975 - val_loss: 0.5120
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7893 - loss: 0.5202 - val_accuracy: 0.7975 - val_loss: 0.5098
# Epoch 15/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7982 - loss: 0.5087 - val_accuracy: 0.7975 - val_loss: 0.5082
# Epoch 16/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7972 - loss: 0.5082 - val_accuracy: 0.7975 - val_loss: 0.5070
# Epoch 17/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7911 - loss: 0.5143 - val_accuracy: 0.7975 - val_loss: 0.5061
# Epoch 18/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7982 - loss: 0.5051 - val_accuracy: 0.7975 - val_loss: 0.5054
# Epoch 19/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7910 - loss: 0.5133 - val_accuracy: 0.7975 - val_loss: 0.5049
# Epoch 20/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7928 - loss: 0.5108 - val_accuracy: 0.7975 - val_loss: 0.5046
# Epoch 21/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7969 - loss: 0.5052 - val_accuracy: 0.7975 - val_loss: 0.5043
# Epoch 22/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7960 - loss: 0.5063 - val_accuracy: 0.7975 - val_loss: 0.5042
# Epoch 23/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7957 - loss: 0.5065 - val_accuracy: 0.7975 - val_loss: 0.5041
# Epoch 24/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7923 - loss: 0.5110 - val_accuracy: 0.7975 - val_loss: 0.5040
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8001 - loss: 0.5005 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 26/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7879 - loss: 0.5168 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7972 - loss: 0.5043 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7999 - loss: 0.5007 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 29/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7980 - loss: 0.5032 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.5030 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 31/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7933 - loss: 0.5096 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 32/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7936 - loss: 0.5091 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 33/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8037 - loss: 0.4954 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 34/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7972 - loss: 0.5043 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 35/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7976 - loss: 0.5037 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 36/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7956 - loss: 0.5065 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7983 - loss: 0.5027 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7970 - loss: 0.5046 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7966 - loss: 0.5051 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8014 - loss: 0.4985 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 41/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7965 - loss: 0.5052 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 42/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7998 - loss: 0.5007 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 43/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7891 - loss: 0.5153 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 44/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7973 - loss: 0.5041 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 45/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7990 - loss: 0.5018 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 46/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7900 - loss: 0.5140 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 47/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7931 - loss: 0.5099 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 48/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7901 - loss: 0.5140 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 49/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7915 - loss: 0.5120 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 50/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7960 - loss: 0.5060 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 51/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7957 - loss: 0.5063 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 52/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7981 - loss: 0.5031 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 53/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7886 - loss: 0.5159 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 54/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7969 - loss: 0.5047 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 55/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8008 - loss: 0.4993 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 56/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7990 - loss: 0.5018 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 57/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7962 - loss: 0.5056 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 58/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7916 - loss: 0.5119 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 59/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7984 - loss: 0.5027 - val_accuracy: 0.7975 - val_loss: 0.5039
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 49.

# %%
classifier1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 3)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            12 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             4 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │             8 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 3)              │            15 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 239 (960.00 B)
#  Trainable params: 79 (316.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 160 (644.00 B)

# %%
loss, accuracy = classifier1.evaluate(X_test, y_test)
print(f'Test Loss: {loss}')
print(f'Test Accuracy: {accuracy}')
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7909 - loss: 0.5129
# Test Loss: 0.5038505792617798
# Test Accuracy: 0.7975000143051147

# %%
# Step 10: Plot training history (loss and accuracy)
# Plot the training and validation loss over epochs
plt.figure(figsize=(12, 6))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred = classifier1.predict(X_test)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step

# %%
y_pred
# Out:
# array([[0.20330013],
#        [0.20330013],
#        [0.20330013],
#        ...,
#        [0.20330013],
#        [0.20330013],
#        [0.20330013]], dtype=float32)

# %%
y_pred = (y_pred > 0.5)
y_pred
# Out:
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(cm)
print("\n")
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy Score:", accuracy)
print("\n")

report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Confusion Matrix:
# [[1595    0]
#  [ 405    0]]
#
#
# Accuracy Score: 0.7975
#
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1595
#            1       0.00      0.00      0.00       405
#
#     accuracy                           0.80      2000
#    macro avg       0.40      0.50      0.44      2000
# weighted avg       0.64      0.80      0.71      2000
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from tensorflow import keras
from tensorflow.keras.utils import plot_model

# Generate the visualization of the model's architecture
plot_model(classifier1, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

from IPython.display import Image
Image('model_architecture.png')
